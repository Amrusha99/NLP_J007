# %% [markdown]
# <a href="https://colab.research.google.com/github/Amrusha99/NLP_J007/blob/master/Word_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_json("http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz", lines=True)
df.head()
# Out:
#        reviewerID        asin  ... unixReviewTime   reviewTime
# 0  A32T2H8150OJLU  B00000JBLH  ...     1094169600   09 3, 2004
# 1  A3MAFS04ZABRGO  B00000JBLH  ...     1197676800  12 15, 2007
# 2  A1F1A0QQP2XVH5  B00000JBLH  ...     1293840000   01 1, 2011
# 3   A49R5DBXXQDE5  B00000JBLH  ...     1145404800  04 19, 2006
# 4  A2XRMQA6PJ5ZJ8  B00000JBLH  ...     1375574400   08 4, 2013
#
# [5 rows x 9 columns]

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = STOPWORDS, 
                min_font_size = 10).generate(str(df.reviewText.values))

# %%
# plot the WordCloud image                        
plt.figure(figsize = (20, 15), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(df.reviewText[0:10])
feature_names = vectorizer.get_feature_names()
dense = vectors.todense()
denselist = dense.tolist()
dt = pd.DataFrame(denselist, columns=feature_names)
dt
# Out:
#          10        11       11c  ...     years       you      your
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.118565  0.000000
# 1  0.000000  0.000000  0.016578  ...  0.009844  0.000000  0.056372
# 2  0.000000  0.116317  0.000000  ...  0.138143  0.000000  0.000000
# 3  0.030105  0.000000  0.000000  ...  0.035754  0.161611  0.076775
# 4  0.000000  0.000000  0.000000  ...  0.061063  0.110406  0.000000
# 5  0.000000  0.000000  0.000000  ...  0.000000  0.086257  0.000000
# 6  0.000000  0.000000  0.000000  ...  0.048195  0.174277  0.000000
# 7  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.000000  0.225066  0.000000
# 9  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
# [10 rows x 815 columns]
